# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
# read the combined txt file into dataframe
mta = pd.read_csv("/Users/monkeyjiashuo/Documents/GitHub/sf19_ds15/curriculum/project-01/Project-Benson/Data Files/combined_file.txt")

# %%
# check the # of rows&columns and data types in dataframe
mta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2653353 entries, 0 to 2653352
# Data columns (total 11 columns):
# C/A                                                                     object
# UNIT                                                                    object
# SCP                                                                     object
# STATION                                                                 object
# LINENAME                                                                object
# DIVISION                                                                object
# DATE                                                                    object
# TIME                                                                    object
# DESC                                                                    object
# ENTRIES                                                                 int64
# EXITS                                                                   int64
# dtypes: int64(2), object(9)
# memory usage: 222.7+ MB

# %%
# randomly sample 50 instances to get sense of dataframe
mta.sample(10, random_state = 22)
# Out:
#           C/A  UNIT       SCP         STATION   LINENAME DIVISION        DATE  \
# 172329   R325  R388  00-00-00        E 180 ST         25      IRT  02/28/2019
# 1006422  R610  R057  00-03-00  ATL AV-BARCLAY  2345BDNQR      IRT  03/24/2019
# 1827071  R644  R135  01-06-01      NEWKIRK AV         25      IRT  04/24/2019
# 2111601  N220  R155  01-00-04  KINGSBRIDGE RD         BD      IND  05/08/2019
# 32320    H012  R268  01-06-00      LORIMER ST         LG      BMT  02/24/2019
# 714623   N553  R422  00-00-00        BAY PKWY          F      IND  03/18/2019
# 413260   A039  R085  01-03-00        8 ST-NYU        NRW      BMT  03/14/2019
# 1064394  N049  R084  01-00-02  59 ST COLUMBUS      ABCD1      IND  04/02/2019
# 1155098  R158  R084  00-05-04  59 ST COLUMBUS      1ABCD      IRT  04/05/2019
# 2504686  N072  R012  05-03-05  34 ST-PENN STA        ACE      IND  05/24/2019
#
#              TIME     DESC   ENTRIES  \
# 172329   20:00:00  REGULAR    961978
# 1006422  08:00:00  REGULAR   4894176
# 1827071  09:00:00  REGULAR    569211
# 2111601  21:00:00  REGULAR   1363606
# 32320    20:00:00  REGULAR   1965101
# 714623   09:00:00  REGULAR   1746501
# 413260   04:00:00  REGULAR   2815921
# 1064394  08:00:00  REGULAR   1762763
# 1155098  04:00:00  REGULAR    458752
# 2504686  16:00:00  REGULAR  11053235
#
#          EXITS
# 172329                                             1125241
# 1006422                                           33117307
# 1827071                                            9959298
# 2111601                                            2315045
# 32320                                              1323566
# 714623                                             1663230
# 413260                                             6301047
# 1064394                                            1376352
# 1155098                                                 97
# 2504686                                            5087776

# %%
mta['DATE'] = pd.to_datetime(mta['DATE'], format = '%m/%d/%Y')

# %%
mta['DAY_OF_WEEK'] = mta['DATE'].dt.strftime('%A')

# %%
mta.head(10)
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION       DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-02-23  03:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-02-23  07:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-02-23  11:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-02-23  15:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-02-23  19:00:00
# 5  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-02-23  23:00:00
# 6  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-02-24  03:00:00
# 7  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-02-24  07:00:00
# 8  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-02-24  11:00:00
# 9  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-02-24  15:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6955483
# 1  REGULAR  6955494
# 2  REGULAR  6955554
# 3  REGULAR  6955714
# 4  REGULAR  6956004
# 5  REGULAR  6956147
# 6  REGULAR  6956177
# 7  REGULAR  6956184
# 8  REGULAR  6956215
# 9  REGULAR  6956315
#
#    EXITS                                                                 \
# 0                                            2359112
# 1                                            2359125
# 2                                            2359199
# 3                                            2359248
# 4                                            2359292
# 5                                            2359325
# 6                                            2359332
# 7                                            2359339
# 8                                            2359388
# 9                                            2359432
#
#   DAY_OF_WEEK
# 0    Saturday
# 1    Saturday
# 2    Saturday
# 3    Saturday
# 4    Saturday
# 5    Saturday
# 6      Sunday
# 7      Sunday
# 8      Sunday
# 9      Sunday

# %%
# gb.apply(lambda _df: _df.sort_values(by=['id'])
# mta.groupby(['STATION','DATE'])['TIME'].nunique()

# %%
# mask_6 = [mta.groupby(['STATION','DATE'])['TIME'].nunique() != 6]

# %%
mta_filter = pd.DataFrame(mta.groupby(['STATION','DATE'])['TIME'].nunique())

# %%
mta_filter.loc[mta_filter['TIME'] != 6]
# Out:
#                             TIME
# STATION         DATE
# 1 AV            2019-03-07     8
#                 2019-03-10     5
#                 2019-03-14     7
#                 2019-03-29     8
#                 2019-04-05     7
#                 2019-04-12     7
#                 2019-04-26     8
#                 2019-04-29     7
#                 2019-05-02     7
#                 2019-05-03     7
#                 2019-05-07     8
#                 2019-05-13    10
#                 2019-05-15    11
#                 2019-05-16    10
#                 2019-05-17    11
#                 2019-05-21    10
#                 2019-05-23     8
# 103 ST          2019-03-04     7
#                 2019-03-07     7
#                 2019-03-13    10
#                 2019-03-14     7
#                 2019-03-30     8
#                 2019-04-01     8
#                 2019-04-03     9
#                 2019-04-10     7
#                 2019-04-12     8
#                 2019-04-13    15
#                 2019-04-15     7
#                 2019-05-01     7
#                 2019-05-07    10
# ...                          ...
# WORLD TRADE CTR 2019-05-02     8
#                 2019-05-13     8
#                 2019-05-15     7
#                 2019-05-16     8
#                 2019-05-17     8
#                 2019-05-21     8
# WTC-CORTLANDT   2019-03-05     7
#                 2019-03-07     7
#                 2019-03-14     7
#                 2019-03-29     8
#                 2019-03-31     7
#                 2019-04-03     7
#                 2019-04-10     8
#                 2019-04-12     8
#                 2019-04-17     7
#                 2019-04-24     7
#                 2019-04-29     7
#                 2019-05-02    12
#                 2019-05-03     9
#                 2019-05-07     9
#                 2019-05-14     7
#                 2019-05-15     7
#                 2019-05-21     7
#                 2019-05-23     7
#                 2019-05-24     7
# YORK ST         2019-03-05    11
#                 2019-03-07     7
#                 2019-03-13     7
#                 2019-03-14     7
#                 2019-03-29     8
#
# [7032 rows x 1 columns]
